# %%
import matplotlib 
matplotlib.use('Agg')

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# We follow the basic FITS tutorial provided [in the astropy tutorial](http://docs.astropy.org/en/stable/generated/examples/io/plot_fits-image.html#sphx-glr-generated-examples-io-plot-fits-image-py).

# %% [markdown]
# Setup the plotting style

# %%
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

# %% [markdown]
# Download the data

# %%
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits

image_file = get_pkg_data_filename('tutorials/FITS-images/HorseHead.fits')
# Out:
# Downloading http://data.astropy.org/tutorials/FITS-images/HorseHead.fits [Done]

# %% [markdown]
# We will printo the information in the FITS file
#
# - The first column is an integer indicating the Header Data Unit (HDU).
# HDU is the highest level of data storage. Inside you usually find tables or images.
# - The second column is the name of that HDU.
# - The third column is the type
# - The fifth column are the dimensions.
# - The sixth column is the data type

# %%
fits.info(image_file)
# Out:
# Filename: /Users/forero/.astropy/cache/download/py3/2c9202ae878ecfcb60878ceb63837f5f
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     161   (891, 893)   int16
#   1  er.mask     TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %% [markdown]
# In this example the HDU 0 is name of the HDU. It has two dimensions: (891,893) and stores integer numbers. This is an image. We can extract it as follows

# %%
image_data = fits.getdata(image_file, ext=0)

# %%
type(image_data) # this is a numpy array
# Out:
# numpy.ndarray

# %%
plt.figure()
plt.imshow(image_data)
plt.colorbar()

# %% [markdown]
# you can use slicing to plot image subsets

# %%
plt.figure()
plt.imshow(image_data[:200,700:])
plt.colorbar()

# %%
table_data
# Out:
# FITS_rec([ (-3.1200000000000001, -3.1200000000000001, 0.089999999999999997, 0.040000000000000001),
#        (-2.96, -3.1200000000000001, 0.02, 0.070000000000000007),
#        (-2.7999999999999998, -3.1200000000000001, -0.070000000000000007, 0.14999999999999999),
#        ..., (2.7999999999999998, 3.1200000000000001, 0.0, 0.0),
#        (2.96, 3.1200000000000001, 0.0, 0.0),
#        (3.1200000000000001, 3.1200000000000001, 0.0, 0.0)],
#       dtype=(numpy.record, [('XI', 'S6'), ('ETA', 'S6'), ('XI_CORR', 'S6'), ('ETA_CORR', 'S6')]))
